# %%
# !pip install  pandas
# !pip install  psycopg2-binary
#imports
# Out:
# ...
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# ...
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
#imports
import psycopg2
import pandas as pd

# %%
conn = psycopg2.connect(host="localhost",database="eleicao2018", user="postgres", password="1234")
result_set= pd.read_sql_query("""select * from despesas_candidatos limit 10;""",conn)
result_set
# Out:
#   dt_geracao hh_geracao  ano_eleicao  cd_tipo_eleicao nm_tipo_eleicao  \
# 0 2019-02-14   08:52:37         2018                2       Ordinária
# 1 2019-02-14   08:52:37         2018                2       Ordinária
# 2 2019-02-14   08:52:37         2018                2       Ordinária
# 3 2019-02-14   08:52:37         2018                2       Ordinária
# 4 2019-02-14   08:52:37         2018                2       Ordinária
# 5 2019-02-14   08:52:37         2018                2       Ordinária
# 6 2019-02-14   08:52:37         2018                2       Ordinária
# 7 2019-02-14   08:52:37         2018                2       Ordinária
# 8 2019-02-14   08:52:37         2018                2       Ordinária
# 9 2019-02-14   08:52:37         2018                2       Ordinária
#
#    cd_eleicao                  ds_eleicao dt_eleicao  st_turno  \
# 0         297  Eleição Geral Federal 2018 2018-07-10         1
# 1         297  Eleição Geral Federal 2018 2018-07-10         1
# ...
